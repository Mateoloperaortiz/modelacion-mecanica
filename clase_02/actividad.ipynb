# %% [markdown]
# (c) Juan Gomez 2019. Thanks to Universidad EAFIT for support.

# %% [markdown]
# # Actividad de practica

# %% [markdown]
# Utilizando los ejemplos de la clase crear un notebook que contenga las siguientes partes:
#
# * Una celda de **texto** con un párrafo breve en el que usted indique las ventajas y desventajas de la educación remota y de la educación presencial.
#
# * Una celda de **texto** que contenga una imagen.
#
# * Una celda de **código** que grafique la función $f(x) = 4x+5$ para $x = [0 , 10]$.
#
# * Una celda de **código** en la que importe el modulo necesario para dar estilo al notebook.

# %% [markdown]
# * **Ventajas:** la posibilidad de manejar el tiempo de una manera mas eficiente y tambien poder dedicar tiempo libre en otras cosas.
#
# * **Desventajas:** la dificultad que genera el aprendizaje en linea como: problemas con el internet, desinteres, pereza, entre otras.

# %% [markdown]
# ![Bridge.jpeg](attachment:Bridge.jpeg)

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

def fx(x):
    return 4.0*x+5.0


npts = 200
yy = np.zeros((npts))
xx = np.linspace(0, 10, npts)
yy[:] = fx(xx[:])
plt.figure(0)
plt.plot(xx, yy, 'r--')
