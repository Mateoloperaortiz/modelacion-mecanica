# %% [markdown]
# (c) Juan Gomez 2019. Thanks to Universidad EAFIT for support.

# %% [markdown]
# # Ecuaciones diferenciales ordinarias

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
import sympy as sym
import scipy as sp
from IPython.display import Image

# %% [markdown]
# ### Solución numérica
#
# La función **odeint** de **scipy** permite determinar la solución numérica de ecuaciones diferenciales.
#
# * Tras discutir con el profesor los diferentes pasos del siguiente proceso de solución tome nota en su NoteBook de manera que posteriormente lo pueda usar para resolver otras ecuaciones.

# %%
def model(z , x ):
    """

    """
    y = z[0]

    dydt = -2*x*y
    dzdt = [dydt ]
    
    return dzdt

# %%
#
plt.figure(2)
x_min = -1.5
x_max = +1.5
y_min = -3.0
y_max = +4.0
y0 = [0.40]                              
x  = np.linspace(x_min , x_max , 101)    
#------Integrate---------
#
sol  = odeint(model , y0 , x )
#
#------Plot---------
#
plt.show()
plt.xlim(x_min , x_max)
plt.ylim(y_min , y_max)
plt.plot(x , sol)
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
# Execute this cell to load the notebook's style sheet, then ignore it
from IPython.core.display import HTML
css_file = 'estilo.css'
HTML(open(css_file, "r").read())
# Out:
# <link href="https://fonts.googleapis.com/css?family=Merriweather:300,300i,400,400i,700,700i,900,900i" rel='stylesheet' >
# <link href="https://fonts.googleapis.com/css?family=Source+Sans+Pro:300,300i,400,400i,700,700i" rel='stylesheet' >
# <link href='http://fonts.googleapis.com/css?family=Source+Code+Pro:300,400' rel='stylesheet' >
# <style>
#
# @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
#
#
# #notebook_panel { /* main background */
#     background: rgb(245,245,245);
# }
#
# div.cell { /* set cell width */
#     width: 800px;
# }
#
# div #notebook { /* centre the content */
#     background: #fff; /* white background for content */
#     width: 1000px;
#     margin: auto;
#     padding-left: 0em;
# }
#
# #notebook li { /* More space between bullet points */
# margin-top:0.5em;
# }
#
# /* draw border around running cells */
# div.cell.border-box-sizing.code_cell.running {
# ...
