# %% [markdown]
# # Tarea 2 (5%)
#
# # Discretización de dominios en elementos finitos
#
# ## Equipo # xx
#
# - Integrante 1
#
# - Integrante 2
#
# - Integrante 3

# %% [markdown]
# <div class="alert alert-success">
#
# Usando `gmsh` y el siguiente conjunto de paramétros
#
# * $h_1 = 1.0 m$
#
# * $h_2 = 3.0 m$
#
# * $h_3 = 5.0 m$
#
# * $h_4 = 6.0 m$
#
# * $w_1 = 10.0 m$
#
# * $w_2 = 1.0 m$
#
# * $w_3 = 4.0 m$
#
# * $w_4 = 6.0 m$
#
# * $t_1 = 1.0 m$
#
# mallar el dominio mostrado en la figura.
#
#
# </div>

# %% [markdown]
# <center>
#     <img src="img/pilotes.png"
#          alt="Diagrama de la presa."
#          style="width:800px">
# </center>

# %% [markdown]
# ## Entregables y conidiciones de calificación
#
# Se deben someter los siguientes entregables:
#
# * Imagen del mapa de líneas incluyendo identificación de los puntos, identificación y sentido de las líneas, identificación y sentido de los planos (o line loops) e identificación de las superficies físicas. La imagen debe estar incorporada al notebook.
#
# * Archivo .geo con la geometría parametrizada.
#
# * Archivo .msh con la malla correspondiente.
#
# * La tarea no recibirá puntos si la malla no puede ser visualizada automaticamente con `gmsh` o si no hay consistencia entre el archivo .geo y el mapa de líneas.

# %%
# Execute this cell to load the notebook's style sheet, then ignore it
from IPython.core.display import HTML
css_file = 'estilo.css'
HTML(open(css_file, "r").read())
# Out:
# <link href="https://fonts.googleapis.com/css?family=Merriweather:300,300i,400,400i,700,700i,900,900i" rel='stylesheet' >
# <link href="https://fonts.googleapis.com/css?family=Source+Sans+Pro:300,300i,400,400i,700,700i" rel='stylesheet' >
# <link href='http://fonts.googleapis.com/css?family=Source+Code+Pro:300,400' rel='stylesheet' >
# <style>
#
# @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
#
#
# #notebook_panel { /* main background */
#     background: rgb(245,245,245);
# }
#
# div.cell { /* set cell width */
#     width: 800px;
# }
#
# div #notebook { /* centre the content */
#     background: #fff; /* white background for content */
#     width: 1000px;
#     margin: auto;
#     padding-left: 0em;
# }
#
# #notebook li { /* More space between bullet points */
# margin-top:0.5em;
# }
#
# /* draw border around running cells */
# div.cell.border-box-sizing.code_cell.running {
# ...
